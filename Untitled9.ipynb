# %%
import requests,bs4,time,pyperclip
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
driver_loc = "C:/Users/Lenovo/pywork/chromedriver/chromedriver.exe"
options = webdriver.ChromeOptions()
options.add_argument("window-size = 1920x1080")
driver = webdriver.Chrome(driver_loc, options = options)

url = 'https://www.youtube.com/'
driver.get(url)
time.sleep(1.5)

inputSearch = '스마트밴드'

tag_search = driver.find_element_by_name('search_query')
search_btn = driver.find_element_by_id('search-icon-legacy')
# filter_btn = driver.find_element_by_xpath('//*[@id="button"]/paper-ripple')
# thisYear_btn = driver.find_element_link_text('올해')
# veiws_btn = driver.find_element_link_text('조회수')

tag_search.click()
pyperclip.copy(inputSearch)
tag_search.send_keys(Keys.CONTROL, 'v')

time.sleep(0.5)

search_btn.click()
time.sleep(2)

# filter_btn.click()
# time.sleep(1)

# thisYear_btn.click()
# time.sleep(1)

# views_btn.click()
# time.sleep(1)

data = driver.page_source

bs = bs4.BeautifulSoup(data, 'html.parser')

divTag = bs.findAll(name = 'ytd-video-renderer',
                attrs = {'class': 'style-scope ytd-item-section-renderer'})
divTag[1]
# Out:
# <ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup=""><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=ktYr7FCz2wA" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/ktYr7FCz2wA/hqdefault.jpg?sqp=-oaymwEZCNACELwBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLDs2kEHs1lbCVwmkvGsZwZv8UZKyw" width="246"/></yt-img-shadow>
# ...
