# %% [markdown]
# # 다나와스마트밴드

# %%
import pandas as pd 
import numpy as np

danawaBandData = pd.read_csv('./smartBand.csv')
danawaBandData.head()

# danawaBandData.info()
# danawaBandData.dtypes

# 필요없는 컬럼값들 drop으로 제외.

bandData = danawaBandData.drop(['사이트주소','등록년월','운영체제','블루투스버전','안드로이드OS','iOS',
                                '화면크기','모바일AP','코어갯수', '3D터치센서', '나침반센서','조도센서',
                                '승마', '스키', '골프', '심전도','일립티컬','로잉머신', '여성 건강 모니터링',
                                '시계줄넓이', '적합성평가인증', '안전확인인증'], axis = 1)
# BandData.dtypes
# 데이터프레임 확인
bandData.head()
# Out:
#            제품명     최저가  제조회사     분류   인프라   모양    패널종류      해상도       시스템램  \
# 0    샤오미 미 밴드4   26939   샤오미  스마트밴드  블루투스  사각형  AMOLED  240x120  램 : 512KB
# 1  삼성전자 갤럭시 핏e   35910  삼성전자  스마트밴드  블루투스  사각형  PMOLED   128x64  램 : 128KB
# 2   삼성전자 갤럭시 핏  103490  삼성전자  스마트밴드  블루투스  사각형  AMOLED  240x120    램 : 2MB
# 3     화웨이 밴드 4   29000   화웨이  스마트밴드  블루투스  사각형     NaN   160x80  램 : 384KB
# 4    샤오미 미 밴드3   21120   샤오미  스마트밴드  블루투스  사각형    OLED   128x80        NaN
#
#        내장메모리  ... 분실방지 생활방수 전자결제 알람시계 전용앱지원   배터리용량        사용시간 무게(본체) 방수/방진  \
# 0  저장 : 16MB  ...  NaN  NaN  NaN    ○     ○  135mAh    평균사용:20일  22.1g  5ATM
# 1        NaN  ...  NaN    ○  NaN  NaN     ○   70mAh  평균사용:6일~7일    15g  5ATM
# 2  저장 : 32MB  ...  NaN    ○  NaN  NaN     ○  120mAh  평균사용:7일~8일    23g  5ATM
# 3   저장 : 1MB  ...  NaN    ○  NaN  NaN   NaN   91mAh  평균사용:1일~7일    24g  5ATM
# 4        NaN  ...  NaN  NaN  NaN  NaN     ○  110mAh         NaN   약20g  5ATM
#
#       형태
# 0  밴드분리형
# 1  밴드일체형
# 2  밴드일체형
# ...

# %%
b1 = bandData.loc[bandData.분실방지 ==  "○"] 
b1
# Out:
#                                제품명     최저가    제조회사      분류   인프라   모양  \
# 8       퓨전FNC VPULSE Fit-Coach Go+   32760   퓨전FNC   스마트밴드  블루투스  NaN
# 16                       샤오미 미 밴드2  124030     샤오미   스마트밴드  블루투스  사각형
# 20             삼성전자 기어 핏2 프로 Large  311190    삼성전자   스마트밴드  블루투스  사각형
# 26             삼성전자 기어 핏2 프로 Small  311190    삼성전자   스마트밴드  블루투스  사각형
# 28                코아 I5 Plus 스마트밴드   29900      코아   스마트밴드  블루투스  사각형
# 29             IWOWN I5 Plus 스마트밴드   25800   IWOWN   스마트밴드  블루투스  사각형
# 31                          아비람 S2   36070     아비람   스마트밴드  블루투스  사각형
# 38                       삼성전자 기어 핏  202740    삼성전자   스마트밴드  블루투스  사각형
# 39                        코아 CK HR   35900      코아   스마트밴드  블루투스  사각형
# 40                          코아 CK7   43900      코아   스마트밴드  블루투스  사각형
# 42                      화웨이 아너밴드 4   38610     화웨이   스마트밴드  블루투스  사각형
# 45                    Garmin 비보스포츠  188300  Garmin   스마트밴드  블루투스  사각형
# ...

# %%
b1 = bandData.loc[bandData.패널종류 ==  "LED"]
b1
# Out:
#                  제품명     최저가          제조회사     분류   인프라   모양 패널종류     해상도  \
# 52       화웨이 B29 GPS  125460           화웨이  스마트밴드  블루투스  사각형  LED  128x32
# 58         핏빗 Flex 2  112960            핏빗  스마트밴드  블루투스  사각형  LED     NaN
# 64   Chuangzaozhe W5   34770  Chuangzaozhe  스마트밴드  블루투스  NaN  LED     NaN
# 98        조본 UP move   38000            조본  스마트밴드  블루투스   원형  LED     NaN
# 107          핏빗 Flex  128990            핏빗  스마트밴드  블루투스  사각형  LED     NaN
# 122          화웨이 B29  125460           화웨이  스마트밴드  블루투스  사각형  LED  128x32
# 124            미오 퓨즈  187460            미오  스마트밴드  블루투스  사각형  LED     NaN
# 126            직토 워크  129000            직토  스마트밴드  블루투스  사각형  LED     NaN
# 128            조본 UP  176400            조본  스마트밴드  블루투스  NaN  LED     NaN
#
#     시스템램 내장메모리  ... 분실방지 생활방수 전자결제 알람시계 전용앱지원   배터리용량         사용시간  \
# 52   NaN   NaN  ...  NaN  NaN  NaN    ○     ○  100mAh     평균사용:21일
# 58   NaN   NaN  ...    ○    ○  NaN  NaN     ○     NaN      평균사용:5일
# ...

# %%
bandData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 59 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     131 non-null    object
#  1   최저가     131 non-null    object
#  2   제조회사    113 non-null    object
#  3   분류      131 non-null    object
#  4   인프라     121 non-null    object
#  5   모양      114 non-null    object
#  6   패널종류    83 non-null     object
#  7   해상도     36 non-null     object
#  8   시스템램    11 non-null     object
#  9   내장메모리   11 non-null     object
#  10  WiFi    2 non-null      object
#  11  GPS     20 non-null     object
#  12  NFC     14 non-null     object
#  13  심박센서    59 non-null     object
#  14  가속도센서   50 non-null     object
#  15  만보기센서   24 non-null     object
#  16  자이로센서   26 non-null     object
#  17  기압센서    9 non-null      object
#  18  자외선센서   2 non-null      object
#  19  모션센서    3 non-null      object
#  20  걷기      30 non-null     object
# ...

# %%
bandData[bandData.걷기.isin[]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-344b7aae679e> in <module>
# ----> 1 bandData.최저가.astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...
