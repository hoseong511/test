# %%
[심심할때 풀어보면 좋은문제]
https://www.coupang.com/np/categories/194810

첫페이지에 있는 상품 가격명(타이틀) 및 가격정보를 추출하세요
[단, 쿠팡 크롤링시 나는 크롤러가 아닌것처럼 헤더를 변경해야함!
# 크롤링 헤더변경 필요
url = 'https://www.coupang.com/np/categories/194810?page=1'
# 헤더 변경 나는 크롤러가 아니라 매킨토시 mac으로 접근하고 있다~ 요런 정보임
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',}
data=requests.get(url,headers=headers)

* 그래도 심심하면 전체 페이지 크롤링  
페이지번호 증가하는 패턴 활용하면 가능함 (끝나는조건은 별도 생성필요!)
https://www.coupang.com/np/categories/194810?page=2
 [심심할때 풀어보면 좋은문제]
http://www.ssg.com/search.ssg?target=all&query=%EA%B3%84%EB%9E%80
첫페이지에 있는 상품 가격명(타이틀) 및 가격정보를 추출하세요

* 전체페이지는 셀레니움 학습 후~

# %%
# [그래도 심심하면 전체페이지 크롤링]
# 라이브러리 선언
import requests, bs4
import pandas as pd

# 크롤링을 위한 헤더변경
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',}

# 빈 리스트 만들기
totalList = []

i = 0
# 페이지 1 부터 끝까지 돌리기 위한 반복문! -> i = -1 이면 탈출
while i >= 0 :
    # url에서 page= 뒤가 페이지 수 -> i = 0 부터 들어가면 page=1이 됨
    url = 'https://www.coupang.com/np/categories/194810?page='+ str(i+1)
    
    # 웹페이지 요청
    data=requests.get(url,headers=headers)
    html = data.text
    bs = bs4.BeautifulSoup(html, "html.parser")
    
    # 페이지 18부터 상품정보없음을 나타내는 태그 p의 속성 no-list-item이 나타남
    exit = bs.find(name = 'p',
                  attrs = 'no-list-item')
    
    # try except문 활용
    try:
        # exit가 없을 때 텍스트화하면 오류가 발생해서 except로 넘김
        # (-> 페이지 17까지는 exit가 없기에 텍스트화 불가능)
        exit = exit.text
        # i = -1로 저장 후 반복문 탈출!
        i = -1    
        
    except:
        aTags = bs.findAll(name = "a",
                    attrs = {"class" : "baby-product-link"})

        
        aTagsLen = len(aTags)

        # 상품 이름과 가격을 넣을 반복문
        for j in range(0,aTagsLen):
            # 이름과 가격을 aTags에서 찾아내기 -> 태그 이름이 각각 div(속성 'name'), strong
            eachName = aTags[j].find(name = "div",
                                     attrs = "name")
            eachPrice = aTags[j].find(name = "strong")

            # 텍스트화해서 필요한 이름과 가격 추출
            eachName_text = eachName.text.replace("\n","")
            eachPrice_text = eachPrice.text + "원"
            # 빈리스트에 넣기
            totalList.append([eachName_text,eachPrice_text])

        i = i + 1
        
# 컬럼명이 상품명과 가경인 데이터 프레임으로 저장
result = pd.DataFrame(totalList, columns=["상품명","가격"])
result
# Out:
#                                                     상품명       가격
# 0                             마이산 맥반석 구운란 30구, 900g, 2개  17,500원
# 1                                 곰곰 반숙란 (냉장), 50g, 20구   7,960원
# 2                                화산석 구운란 60구, 2640g, 1개  18,000원
# 3                             곰곰 맥반석 구운란 30구, 1050g, 1개   9,600원
# 4                                곰곰 무항생제 신선한 대란 30구, 1개   5,780원
# ...                                                 ...      ...
# 1015      선한이웃 동물복지 유정란 40구 60구 80구 친환경 무항생제 HACCP 안...  30,000원
# 1016             바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 30구  21,000원
# 1017             바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 40구  28,000원
# 1018             바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 50구  35,000원
# 1019               강원도 청정 백봉오골계 초란 (무항생제 HACCP 인증), 20구  27,000원
#
# [1020 rows x 2 columns]

# %%
import pandas as pd
import bs4
import requests

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',}
# 헤더 정의

dataFrameList=[]
# 모든 결과를 담을 리스트 생성

for i in range(0, 17):   # 페이지가 17개 있어서 17번 반복합니다.
    url = 'https://www.coupang.com/np/categories/194810?page='+str(i+1)  # URL 뒷자리만 바꾸면서 17페이지까지 이동
    data=requests.get(url,headers=headers) # URL 에서 리스폰스를 받아옵니다
    data.encoding='utf-8'  # 인코딩
    html = data.text       # 원본 소스
    bs = bs4.BeautifulSoup(html, "html.parser")  # BeautifulSoup 로 예쁘게 파싱
    
    products = bs.select("a.baby-product-link")  # 변수 products 는 select로 골라왔으므로 리스트형식입니다.
    columns = []    # 행을 담기위한 리스트

    for product in products:  # products 리스트의 모든 요소들에 대해서
        name = product.select_one("dd.descriptions").select_one(".name").get_text(strip=True)  # 상품명 부분입니다.
        price = product.select_one("dd.descriptions").select_one(".price-value").get_text(strip=True)  # 가격 부분입니다.
        columns.append(name)   # 행에 상품명을 담습니다.
        columns.append(price)  # 행에 가격을 담습니다.
        dataFrameList.append(columns) # 최종결과 리스트에 행을 추가합니다.
        columns = []           # 행은 초기화해줍니다.
        
    




result = pd.DataFrame(dataFrameList, columns=['상품명', '가격']) 
# 최종결과를 dataframe으로 포장합니다.

result
# Out:
#                                                     상품명      가격
# 0                             마이산 맥반석 구운란 30구, 900g, 2개  17,500
# 1                                 곰곰 반숙란 (냉장), 50g, 20구   7,960
# 2                                화산석 구운란 60구, 2640g, 1개  18,000
# 3                             곰곰 맥반석 구운란 30구, 1050g, 1개   9,600
# 4                                곰곰 무항생제 신선한 대란 30구, 1개   5,780
# ...                                                 ...     ...
# 1015  선한이웃 동물복지 유정란 40구 60구 80구 친환경 무항생제 HACCP 안전관리인...  30,000
# 1016             바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 40구  28,000
# 1017             바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 50구  35,000
# 1018             바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 30구  21,000
# 1019               강원도 청정 백봉오골계 초란 (무항생제 HACCP 인증), 20구  27,000
#
# [1020 rows x 2 columns]

# %%
# 라이브러리 선언
import requests, bs4
import pandas as pd

# 크롤링을 위한 헤더변경
url = 'https://www.coupang.com/np/categories/194810?page=1'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',}

# 웹페이지 요청하기 
data=requests.get(url,headers=headers)

# utf-8로 인코딩 -> 한글깨짐 방지
data.encoding = 'utf-8'

# 요청한 웹페이지 텍스트화
html = data.text

# bs4로 html형식으로 파싱
bs = bs4.BeautifulSoup(html, 'html.parser')

# 태그 a의 calss 속성이 baby-product-link를 모두 찾기
# -> 확인을 해보니 태그 a의 class 속성 baby-product-link로 각 상품을 묶음
aTags = bs.findAll(name = "a",
                    attrs = {"class" : "baby-product-link"})

# 빈 리스트 만들기
totalList = []
aTagsLen = len(aTags)

# 상품 이름과 가격을 넣을 반복문
for i in range(0,aTagsLen):
    # 이름과 가격을 dlTags에서 찾아내기 -> 태그 이름이 각각 div(속성 'name'), strong
    eachName = aTags[i].find(name = "div",
                             attrs = "name")
    eachPrice = aTags[i].find(name = "strong")
    
    # 텍스트화해서 필요한 이름과 가격 추출
    eachName_text = eachName.text.replace("\n","")
    eachPrice_text = eachPrice.text + "원"
    # 빈리스트에 넣기
    totalList.append([eachName_text,eachPrice_text])

# 컬럼명이 상품명과 가격인 데이터 프레임으로 저장
result = pd.DataFrame(totalList, columns=["상품명","가격"])
result
# Out:
#                                                   상품명       가격
# 0                           마이산 맥반석 구운란 30구, 900g, 2개  17,500원
# 1                               곰곰 반숙란 (냉장), 50g, 20구   7,960원
# 2                              화산석 구운란 60구, 2640g, 1개  18,000원
# 3                           곰곰 맥반석 구운란 30구, 1050g, 1개   9,600원
# 4                              곰곰 무항생제 신선한 대란 30구, 1개   5,780원
# 5                              곰곰 무항생제 신선한 특란 30구, 1개   5,880원
# 6                              곰곰 무항생제 신선한 왕란 15구, 1개   3,880원
# 7                        수원축협 친환경인증 대란 30구, 1560g, 1개   5,880원
# 8                              수원축협 왕란 15구, 1020g, 1개   3,980원
# 9                            아빠가 만든 구운계란 60구, 2kg, 1개  16,400원
# 10                               축협 특란 60구, 3600g, 1개  11,960원
# 11                         곰곰 무항생제 1등급 신선한 특란 15구, 1개   5,290원
# 12                                수원축협 구이란, 35g, 60개입  15,000원
# 13                     쫀득하고 맛있고 탱탱한 구운란 15구, 675g, 1개   6,990원
# 14                      1등급 계란으로 만든 구운란 20구, 800g, 1개   8,400원
# 15                        수원축협 무항생제 특란 30구, 1800g, 1개   6,990원
# 16                      누리웰 동물복지 백색유정란 20구, 1040g, 1개   8,770원
# 17                         곰곰 동물복지 유정란 20구, 1040g, 1개   6,340원
# 18                가농 금계란 매일 만나는 1+등급 특란 15구, 900g, 1개   5,800원
# 19                      풀무원 무항생제 1등급 계란 15구, 780g, 1개   6,890원
# 20                                 누리웰 깐메추리알, 1kg, 1개   7,580원
# 21                            풍요한아침 반숙란 10구, 520g, 1개   5,800원
# 22      맛군 촉촉쫄깃 구운계란(구운란) 훈제란 30알 60알 90알, 01. 촉촉쫄...   8,900원
# 23                    상하농원 동물복지 순백색 유정란 10구, 520g, 1개   6,500원
# 24             가농 금계란 비타민E 함유 1+등급 특란 30구, 1,800g, 1개   8,400원
# 25                      올계 유기농인증 자연방사 유정란, 300g이상, 1개   4,700원
# 26                        자연애찬 정직한 훈제란 30구, 1200g, 1개  11,940원
# 27                   동물복지 인증 자연은 닮은 계란 30구, 1350g, 1개  10,990원
# 28                 무항생제 인증 햇살계란 친환경 특란 20구, 1200g, 1개   6,490원
# 29                         누리웰 반란이 반숙계란 15구, 750g, 1개   7,400원
# 30                       참나무촌 무염훈제계란, 30개입, 1.2kg(한판)   6,900원
# 31               가농 금계란 비타민E 함유 1+등급 특란 15구, 900g, 1개   4,470원
# 32                         자연애찬 1등급 특란 20구, 1040g, 1개   5,700원
# 33                        자연애찬 1등급 등급란 20구, 1040g, 1개   5,140원
# 34                          누리웰 생생 메추리알 56구, 504g, 1개   4,900원
# 35                       제주 화산석 구운 유정란 30구, 1320g, 1개  15,900원
# 36            가농금계란 갓 낳은 신선한 1+등급 초란 중란 15구, 660g, 1개   6,900원
# 37                쫀득하고 맛있고 탱탱한 동물복지 구운란 20구, 900g, 1개   9,490원
# 38                상하농원 노른자가 진하고 맛있는 영양란 15구, 780g, 1개   5,820원
# 39                                비빔반숙란 15구, 675g, 1개   6,990원
# 40                 무항생제 인증 햇살계란 친환경 대란 20구, 1040g, 1개   6,390원
# 41                    상하농원 순백색 동물복지 유정란 15구, 780g, 1개   9,720원
# 42                     동물복지 인증 새싹보리 유정란 15구, 675g, 1개   6,990원
# 43                가농 금계란 1+등급 특란(당일산란 당일발송), 40개, 60g  12,800원
# 44                         누리웰 무항생제 유정란 15구, 780g, 1개   5,480원
# 45                 CJ프레시웨이 더안심 동물복지 유정란 15구, 780g, 1팩   8,990원
# 46                       [시선] 무항생제 구운계란 1세트, 60개, 35g  12,800원
# 47                    [에그웰] 구운계란 구운란 30구(1판), 1구, 45g   5,400원
# 48                 CJ프레시웨이 무항생제 더안심 건강란 15구, 780g, 1팩   6,990원
# 49                          계림농장 무항생제 반숙란 30구 1판, 1세트  11,900원
# 50              오복유통 HACCP인증 구운계란 2판60구 무료배송, 60구, 2판  13,900원
# 51                      가농 금계란 DHA 오메가3 15구, 900g, 1개   6,750원
# 52                          행복담기 훈제메추리알 15p, 225g, 1개   5,980원
# 53              맛블리 무항생제 구운계란 60구 한세트, 1set, 35g x 60  13,200원
# 54                             감동란 반숙계란 15구, 750g, 1개   9,000원
# 55                        자연애찬 자연愛란 특란 30구, 1800g, 1개   5,980원
# 56                       자연애찬 반숙이 반숙계란 20구, 1000g, 1개   9,750원
# 57                         풍요한 아침 반숙계란 20구, 1040g, 1개   8,960원
# 58                            누리웰 유정란 깐메추리알, 500g, 1개   5,330원
# 59                             오뚜기 1등급란 15구, 780g, 1개   5,990원

# %%
# [그래도 심심하면 전체페이지 크롤링]
# 라이브러리 선언
import requests, bs4
import pandas as pd

# 크롤링을 위한 헤더변경
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',}
totalList = []
i = 0
# 페이지 1 부터 끝까지 돌리기 위한 반복문! -> i = -1 이면 탈출
while i >= 0 :
    # url에서 page= 뒤가 페이지 수 -> i = 0 부터 들어가면 page=1이 됨
    url = 'https://www.coupang.com/np/categories/194810?page='+ str(i+1)
    
    # 웹페이지 요청
    data=requests.get(url,headers=headers)
    html = data.text
    bs = bs4.BeautifulSoup(html, "html.parser")
    exit = bs.find(name = "div",
                   attrs = "name")
    # 페이지 18부터 상품정보없음을 나타내는 태그 p의 속성 no-list-item이 나타남
    
    # try except문 활용
    try:
        exit = exit.text
        # exit가 없을 때 텍스트화하면 오류가 발생해서 except로 넘김
        # (-> 페이지 17까지는 exit가 없기에 텍스트화 불가능)
        
        # 상품 이름과 가격을 넣을 반복문
        aTags = bs.findAll(name = "a",
                    attrs = {"class" : "baby-product-link"})
        
        aTagsLen = len(aTags)
        for j in range(0,aTagsLen):
            # 이름과 가격을 aTags에서 찾아내기 -> 태그 이름이 각각 div(속성 'name'), strong
            eachName = aTags[j].find(name = "div",
                                     attrs = "name")
            eachPrice = aTags[j].find(name = "strong")

            # 텍스트화해서 필요한 이름과 가격 추출
            eachName_text = eachName.text.replace("\n","")
            eachPrice_text = eachPrice.text + "원"
            # 빈리스트에 넣기
            totalList.append([eachName_text,eachPrice_text])

        i = i + 1
        
    except:
        # exit가 없을 때 텍스트화하면 오류가 발생해서 except로 넘김
        # (-> 페이지 17까지는 exit가 없기에 텍스트화 불가능)
#         aTags = aTags.text
        # i = -1로 저장 후 반복문 탈출!
        i = -1    

        
        
# 컬럼명이 상품명과 가경인 데이터 프레임으로 저장
result = pd.DataFrame(totalList, columns=["상품명","가격"])
result
# Out:
#                                              상품명       가격
# 0                      마이산 맥반석 구운란 30구, 900g, 2개  17,500원
# 1                          곰곰 반숙란 (냉장), 50g, 20구   7,960원
# 2                         화산석 구운란 60구, 2640g, 1개  18,000원
# 3                      곰곰 맥반석 구운란 30구, 1050g, 1개   9,600원
# 4                         곰곰 무항생제 신선한 대란 30구, 1개   5,780원
# ...                                          ...      ...
# 1015      바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 30구  21,000원
# 1016      바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 50구  35,000원
# 1017      바로구운란 동물복지 무항생제 1등급 유정란으로 만든 구운계란, 40구  28,000원
# 1018        강원도 청정 백봉오골계 초란 (무항생제 HACCP 인증), 20구  27,000원
# 1019        강원도 청정 백봉오골계 초란 (무항생제 HACCP 인증), 60구  72,000원
#
# [1020 rows x 2 columns]

# %%
# 라이브러리 불러오기
import requests,bs4
import pandas as pd


# 웹페이지 요청 후 가져옴
url = 'http://www.ssg.com/search.ssg?target=all&query=%EA%B3%84%EB%9E%80'
data = requests.get(url)

# data를 인코딩하기
data.encoding = 'utf-8'

# 텍스트화하기
html = data.text

# bs4가 html형식으로 파싱
bs = bs4.BeautifulSoup(html,'html.parser')

# 상품 정보를 포괄하는 태그 div에 class속성이 tmpl_itemlist를 찾기
div_tags = bs.find(name = 'div',
                 attrs = {'class': 'tmpl_itemlist'})

# 태그 div에 class 속성 cunit_info를 모두 찾기
div_info_tags = div_tags.findAll(name = 'div',
                    attrs = {'class':'cunit_info'})

# 빈 리스트 저장 -> 상품명과 가격을 담을 리스트
totalList =[]
div_info_tagsLen = len(div_info_tags)

# 반복문으로 리스트에 담기
for i in range (0, div_info_tagsLen):
    
    # eachName과 eachPrice를 태그 em에 각각 clss속성에 tx_ko, ssg_price
    eachName = div_info_tags[i].find(name = 'em',
                           attrs = {'class':'tx_ko'})
    
    eachPrice = div_info_tags[i].find(name = 'em',
                               attrs = {'class':'ssg_price'})
    
    # 텍스트화하기
    eachName = eachName.text
    eachPrice = eachPrice.text+"원"
    
    # 리스트에 추가하기
    totalList.append([eachName, eachPrice])
    
# 컬럼명이 상품명과 가격인 데이터프레임으로 저장
result = pd.DataFrame(totalList, columns=["상품명","가격"])
result
